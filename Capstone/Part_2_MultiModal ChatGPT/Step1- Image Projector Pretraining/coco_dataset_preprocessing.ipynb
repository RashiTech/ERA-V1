# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/capstone-2')

# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2024-01-25 12:34:27--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 16.182.75.25, 52.217.11.108, 52.216.49.9, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|16.182.75.25|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  54.3MB/s    in 4.4s
#
# 2024-01-25 12:34:31 (54.8 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# !pip install unzip -q
# Out:
# Collecting unzip
#   Downloading unzip-1.0.0.tar.gz (704 bytes)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: unzip
#   Building wheel for unzip (setup.py) ... done
#   Created wheel for unzip: filename=unzip-1.0.0-py3-none-any.whl size=1280 sha256=a079cd3200c15a2bf38e27f905fcfe3a77729ff0c36de8c03b313a9cd0fa60b7
#   Stored in directory: /root/.cache/pip/wheels/80/dc/7a/f8af45bc239e7933509183f038ea8d46f3610aab82b35369f4
# Successfully built unzip
# Installing collected packages: unzip
# Successfully installed unzip-1.0.0

# %%
# !unzip annotations_trainval2017.zip
# Out:
# Archive:  annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
import pickle
import json

# %%
f = open('annotations/captions_train2017.json')
coco_dataset = json.load(f)

# %%
len(coco_dataset['annotations'])
# Out:
# 591753

# %%
# flatten the coco dataset
coco_data_list = []
r = 0
for a_idx, a in enumerate(coco_dataset['annotations']):
    image_id = a['image_id']
    caption  = a['caption']
    for i in coco_dataset['images']:
        if i['id'] == image_id:
            image_url = i['coco_url']
            file_name = i['file_name']
    if a_idx % 50000 == 0:
      print(f"{50000 * r} processed")
      r += 1

    coco_data_list.append([image_id,file_name,image_url,caption])
# Out:
# 0 processed
# 50000 processed
# 100000 processed
# 150000 processed
# 200000 processed
# 250000 processed
# 300000 processed
# 350000 processed
# 400000 processed
# 450000 processed
# 500000 processed
# 550000 processed

# %%
# save as pickle file
with open("coco_dataset_pickle", "wb") as fp:   #Pickling
    pickle.dump(coco_data_list, fp)
