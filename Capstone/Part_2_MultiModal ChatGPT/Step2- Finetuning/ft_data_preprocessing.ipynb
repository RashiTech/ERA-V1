# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/capstone-2')

# %%
import json
import requests
from PIL import Image
import pickle
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
import torch
from torch.utils.data import Dataset
from torch.utils.data import random_split, DataLoader
from transformers import AutoProcessor, AutoTokenizer
import pickle

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# Downloading the Hugging face Instruct150K data
#
# https://huggingface.co/datasets/liuhaotian/LLaVA-Instruct-150K

# %%
# Opening JSON file - instruct150k
f = open('llava_instruct_150k.json')

# returns JSON object as
# a dictionary
data = json.load(f)
data[0]
# Out:
# {'id': '000000033471',
#  'image': '000000033471.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nWhat are the colors of the bus in the image?'},
#   {'from': 'gpt', 'value': 'The bus in the image is white and red.'},
#   {'from': 'human',
#    'value': 'What feature can be seen on the back of the bus?'},
#   {'from': 'gpt', 'value': 'The back of the bus features an advertisement.'},
#   {'from': 'human',
#    'value': 'Is the bus driving down the street or pulled off to the side?'},
#   {'from': 'gpt',
#    'value': 'The bus is driving down the street, which is crowded with people and other vehicles.'}]}

# %% [markdown]
# Preparing Data

# %%
# create input pickle file by flattening the data
data_instruct150_flatten = []
r = 0

for a_idx,d in enumerate(data):
    image = d['image']
    image_url = 'http://images.cocodataset.org/train2017/' + image
    conv_iter = iter( d['conversations'])
    for i in conv_iter:
      gpt_ans = next(conv_iter)
      if len(gpt_ans['value']) > 100: # filter out too long answers
          continue
      if i['from'] == 'human' and gpt_ans['from'] == 'gpt':
        data_instruct150_flatten.append((image_url, i['value'].replace('\n','').replace('',''),gpt_ans['value']))

    if a_idx % 50000 == 0:
      print(f"{50000 * r} processed")
      r += 1
# Out:
# 0 processed
# 50000 processed
# 100000 processed
# 150000 processed

# %%
data_instruct150_flatten[2]
# Out:
# ('http://images.cocodataset.org/train2017/000000033471.jpg',
#  'Is the bus driving down the street or pulled off to the side?',
#  'The bus is driving down the street, which is crowded with people and other vehicles.')

# %%
clip_model_name = "wkcn/TinyCLIP-ViT-61M-32-Text-29M-LAION400M"
phi_model_name  = "microsoft/phi-2"
tokenizer  = AutoTokenizer.from_pretrained(phi_model_name, trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# gpt like training dataset
with open('train_tokens.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows([['img_url','input','label']])

train_data_temp = []
r = 1
for df in data_instruct150_flatten:
  image_url = df[0]
  image_q   = df[1]
  image_a   = df[2]

  # tokenise
  ques_token = tokenizer(image_q, return_tensors="pt", return_attention_mask=False)['input_ids'].squeeze(0)
  ans_token  = tokenizer(image_a, return_tensors="pt", return_attention_mask=False)['input_ids'].squeeze(0)

  context_length = len(ques_token)
  combo_q_a = torch.cat( [ques_token,ans_token])

  for al in range(len(ans_token)):
    input = combo_q_a[al : al + context_length].numpy()
    label = combo_q_a[al + 1 : al + context_length + 1].numpy()
    train_data_temp.append([image_url,input,label])
    if len(train_data_temp) >= 1: # write to the file
       print(f"Writing to disk after {r} rows")
       r += 1
       with open('train_tokens.csv', 'a', newline='') as file:
          writer = csv.writer(file)
          writer.writerows(train_data_temp)
       train_data_temp = []
# Out:
# Streaming output truncated to the last 5000 lines.
# Writing to disk after 186321000000 rows
# Writing to disk after 186321100000 rows
# Writing to disk after 186321200000 rows
# Writing to disk after 186321300000 rows
# Writing to disk after 186321400000 rows
# Writing to disk after 186321500000 rows
# Writing to disk after 186321600000 rows
# Writing to disk after 186321700000 rows
# Writing to disk after 186321800000 rows
# Writing to disk after 186321900000 rows
# Writing to disk after 186322000000 rows
# Writing to disk after 186322100000 rows
# Writing to disk after 186322200000 rows
# Writing to disk after 186322300000 rows
# Writing to disk after 186322400000 rows
# Writing to disk after 186322500000 rows
# Writing to disk after 186322600000 rows
# Writing to disk after 186322700000 rows
# Writing to disk after 186322800000 rows
# Writing to disk after 186322900000 rows
# Writing to disk after 186323000000 rows
# Writing to disk after 186323100000 rows
# Writing to disk after 186323200000 rows
# Writing to disk after 186323300000 rows
# Writing to disk after 186323400000 rows
# Writing to disk after 186323500000 rows
# Writing to disk after 186323600000 rows
# Writing to disk after 186323700000 rows
# Writing to disk after 186323800000 rows
# Writing to disk after 186323900000 rows
# Writing to disk after 186324000000 rows
# Writing to disk after 186324100000 rows
# Writing to disk after 186324200000 rows
# Writing to disk after 186324300000 rows
# Writing to disk after 186324400000 rows
# Writing to disk after 186324500000 rows
# Writing to disk after 186324600000 rows
# Writing to disk after 186324700000 rows
# Writing to disk after 186324800000 rows
# Writing to disk after 186324900000 rows
# Writing to disk after 186325000000 rows
# Writing to disk after 186325100000 rows
# Writing to disk after 186325200000 rows
# Writing to disk after 186325300000 rows
# Writing to disk after 186325400000 rows
# Writing to disk after 186325500000 rows
# Writing to disk after 186325600000 rows
# Writing to disk after 186325700000 rows
# Writing to disk after 186325800000 rows
# Writing to disk after 186325900000 rows
# Writing to disk after 186326000000 rows
# Writing to disk after 186326100000 rows
# Writing to disk after 186326200000 rows
# Writing to disk after 186326300000 rows
# Writing to disk after 186326400000 rows
# Writing to disk after 186326500000 rows
# Writing to disk after 186326600000 rows
# Writing to disk after 186326700000 rows
# Writing to disk after 186326800000 rows
# Writing to disk after 186326900000 rows
# Writing to disk after 186327000000 rows
# Writing to disk after 186327100000 rows
# Writing to disk after 186327200000 rows
# Writing to disk after 186327300000 rows
# Writing to disk after 186327400000 rows
# Writing to disk after 186327500000 rows
# Writing to disk after 186327600000 rows
# Writing to disk after 186327700000 rows
# Writing to disk after 186327800000 rows
# Writing to disk after 186327900000 rows
# Writing to disk after 186328000000 rows
# Writing to disk after 186328100000 rows
# Writing to disk after 186328200000 rows
# Writing to disk after 186328300000 rows
# Writing to disk after 186328400000 rows
# Writing to disk after 186328500000 rows
# Writing to disk after 186328600000 rows
# Writing to disk after 186328700000 rows
# Writing to disk after 186328800000 rows
# Writing to disk after 186328900000 rows
# Writing to disk after 186329000000 rows
# Writing to disk after 186329100000 rows
# Writing to disk after 186329200000 rows
# Writing to disk after 186329300000 rows
# Writing to disk after 186329400000 rows
# Writing to disk after 186329500000 rows
# Writing to disk after 186329600000 rows
# Writing to disk after 186329700000 rows
# Writing to disk after 186329800000 rows
# Writing to disk after 186329900000 rows
# Writing to disk after 186330000000 rows
# Writing to disk after 186330100000 rows
# Writing to disk after 186330200000 rows
# Writing to disk after 186330300000 rows
# Writing to disk after 186330400000 rows
# Writing to disk after 186330500000 rows
# Writing to disk after 186330600000 rows
# Writing to disk after 186330700000 rows
# Writing to disk after 186330800000 rows
# Writing to disk after 186330900000 rows
# Writing to disk after 186331000000 rows
# Writing to disk after 186331100000 rows
# Writing to disk after 186331200000 rows
# Writing to disk after 186331300000 rows
# Writing to disk after 186331400000 rows
# Writing to disk after 186331500000 rows
# Writing to disk after 186331600000 rows
# Writing to disk after 186331700000 rows
# Writing to disk after 186331800000 rows
# Writing to disk after 186331900000 rows
# Writing to disk after 186332000000 rows
# Writing to disk after 186332100000 rows
# Writing to disk after 186332200000 rows
# Writing to disk after 186332300000 rows
# Writing to disk after 186332400000 rows
# Writing to disk after 186332500000 rows
# Writing to disk after 186332600000 rows
# Writing to disk after 186332700000 rows
# Writing to disk after 186332800000 rows
# Writing to disk after 186332900000 rows
# Writing to disk after 186333000000 rows
# Writing to disk after 186333100000 rows
# Writing to disk after 186333200000 rows
# Writing to disk after 186333300000 rows
# Writing to disk after 186333400000 rows
# Writing to disk after 186333500000 rows
# Writing to disk after 186333600000 rows
# Writing to disk after 186333700000 rows
# Writing to disk after 186333800000 rows
# Writing to disk after 186333900000 rows
# Writing to disk after 186334000000 rows
# Writing to disk after 186334100000 rows
# Writing to disk after 186334200000 rows
# Writing to disk after 186334300000 rows
# Writing to disk after 186334400000 rows
# Writing to disk after 186334500000 rows
# Writing to disk after 186334600000 rows
# Writing to disk after 186334700000 rows
# Writing to disk after 186334800000 rows
# Writing to disk after 186334900000 rows
# Writing to disk after 186335000000 rows
# Writing to disk after 186335100000 rows
# Writing to disk after 186335200000 rows
# Writing to disk after 186335300000 rows
# Writing to disk after 186335400000 rows
# Writing to disk after 186335500000 rows
# Writing to disk after 186335600000 rows
# Writing to disk after 186335700000 rows
# Writing to disk after 186335800000 rows
# Writing to disk after 186335900000 rows
# Writing to disk after 186336000000 rows
# Writing to disk after 186336100000 rows
# Writing to disk after 186336200000 rows
# Writing to disk after 186336300000 rows
# Writing to disk after 186336400000 rows
# Writing to disk after 186336500000 rows
# Writing to disk after 186336600000 rows
# Writing to disk after 186336700000 rows
# Writing to disk after 186336800000 rows
# Writing to disk after 186336900000 rows
# Writing to disk after 186337000000 rows
# Writing to disk after 186337100000 rows
# Writing to disk after 186337200000 rows
# Writing to disk after 186337300000 rows
# Writing to disk after 186337400000 rows
# Writing to disk after 186337500000 rows
# Writing to disk after 186337600000 rows
# Writing to disk after 186337700000 rows
# Writing to disk after 186337800000 rows
# Writing to disk after 186337900000 rows
# Writing to disk after 186338000000 rows
# Writing to disk after 186338100000 rows
# Writing to disk after 186338200000 rows
# Writing to disk after 186338300000 rows
# Writing to disk after 186338400000 rows
# Writing to disk after 186338500000 rows
# Writing to disk after 186338600000 rows
# Writing to disk after 186338700000 rows
# Writing to disk after 186338800000 rows
# Writing to disk after 186338900000 rows
# Writing to disk after 186339000000 rows
# Writing to disk after 186339100000 rows
# Writing to disk after 186339200000 rows
# Writing to disk after 186339300000 rows
# Writing to disk after 186339400000 rows
# Writing to disk after 186339500000 rows
# Writing to disk after 186339600000 rows
# Writing to disk after 186339700000 rows
# Writing to disk after 186339800000 rows
# Writing to disk after 186339900000 rows
# Writing to disk after 186340000000 rows
# Writing to disk after 186340100000 rows
# Writing to disk after 186340200000 rows
# Writing to disk after 186340300000 rows
# Writing to disk after 186340400000 rows
# Writing to disk after 186340500000 rows
# Writing to disk after 186340600000 rows
# Writing to disk after 186340700000 rows
# Writing to disk after 186340800000 rows
# Writing to disk after 186340900000 rows
# Writing to disk after 186341000000 rows
# Writing to disk after 186341100000 rows
# Writing to disk after 186341200000 rows
# Writing to disk after 186341300000 rows
# Writing to disk after 186341400000 rows
# Writing to disk after 186341500000 rows
# Writing to disk after 186341600000 rows
# Writing to disk after 186341700000 rows
# Writing to disk after 186341800000 rows
# Writing to disk after 186341900000 rows
# Writing to disk after 186342000000 rows
# Writing to disk after 186342100000 rows
# Writing to disk after 186342200000 rows
# Writing to disk after 186342300000 rows
# Writing to disk after 186342400000 rows
# Writing to disk after 186342500000 rows
# Writing to disk after 186342600000 rows
# Writing to disk after 186342700000 rows
# Writing to disk after 186342800000 rows
# Writing to disk after 186342900000 rows
# Writing to disk after 186343000000 rows
# Writing to disk after 186343100000 rows
# Writing to disk after 186343200000 rows
# Writing to disk after 186343300000 rows
# Writing to disk after 186343400000 rows
# Writing to disk after 186343500000 rows
# Writing to disk after 186343600000 rows
# Writing to disk after 186343700000 rows
# Writing to disk after 186343800000 rows
# Writing to disk after 186343900000 rows
# Writing to disk after 186344000000 rows
# Writing to disk after 186344100000 rows
# Writing to disk after 186344200000 rows
# Writing to disk after 186344300000 rows
# Writing to disk after 186344400000 rows
# Writing to disk after 186344500000 rows
# Writing to disk after 186344600000 rows
# Writing to disk after 186344700000 rows
# Writing to disk after 186344800000 rows
# Writing to disk after 186344900000 rows
# Writing to disk after 186345000000 rows
# Writing to disk after 186345100000 rows
# Writing to disk after 186345200000 rows
# Writing to disk after 186345300000 rows
# Writing to disk after 186345400000 rows
# Writing to disk after 186345500000 rows
# Writing to disk after 186345600000 rows
# Writing to disk after 186345700000 rows
# Writing to disk after 186345800000 rows
# Writing to disk after 186345900000 rows
# Writing to disk after 186346000000 rows
# Writing to disk after 186346100000 rows
# Writing to disk after 186346200000 rows
# Writing to disk after 186346300000 rows
# Writing to disk after 186346400000 rows
# Writing to disk after 186346500000 rows
# Writing to disk after 186346600000 rows
# Writing to disk after 186346700000 rows
# Writing to disk after 186346800000 rows
# Writing to disk after 186346900000 rows
# Writing to disk after 186347000000 rows
# Writing to disk after 186347100000 rows
# Writing to disk after 186347200000 rows
# Writing to disk after 186347300000 rows
# Writing to disk after 186347400000 rows
# Writing to disk after 186347500000 rows
# Writing to disk after 186347600000 rows
# Writing to disk after 186347700000 rows
# Writing to disk after 186347800000 rows
# Writing to disk after 186347900000 rows
# Writing to disk after 186348000000 rows
# Writing to disk after 186348100000 rows
# Writing to disk after 186348200000 rows
# Writing to disk after 186348300000 rows
# Writing to disk after 186348400000 rows
# Writing to disk after 186348500000 rows
# Writing to disk after 186348600000 rows
# Writing to disk after 186348700000 rows
# Writing to disk after 186348800000 rows
# Writing to disk after 186348900000 rows
# Writing to disk after 186349000000 rows
# Writing to disk after 186349100000 rows
# Writing to disk after 186349200000 rows
# Writing to disk after 186349300000 rows
# Writing to disk after 186349400000 rows
# Writing to disk after 186349500000 rows
# Writing to disk after 186349600000 rows
# Writing to disk after 186349700000 rows
# Writing to disk after 186349800000 rows
# Writing to disk after 186349900000 rows
# Writing to disk after 186350000000 rows
# Writing to disk after 186350100000 rows
# Writing to disk after 186350200000 rows
# Writing to disk after 186350300000 rows
# Writing to disk after 186350400000 rows
# Writing to disk after 186350500000 rows
# Writing to disk after 186350600000 rows
# Writing to disk after 186350700000 rows
# Writing to disk after 186350800000 rows
# Writing to disk after 186350900000 rows
# Writing to disk after 186351000000 rows
# Writing to disk after 186351100000 rows
# Writing to disk after 186351200000 rows
# Writing to disk after 186351300000 rows
# Writing to disk after 186351400000 rows
# Writing to disk after 186351500000 rows
# Writing to disk after 186351600000 rows
# Writing to disk after 186351700000 rows
# Writing to disk after 186351800000 rows
# Writing to disk after 186351900000 rows
# Writing to disk after 186352000000 rows
# Writing to disk after 186352100000 rows
# Writing to disk after 186352200000 rows
# Writing to disk after 186352300000 rows
# Writing to disk after 186352400000 rows
# Writing to disk after 186352500000 rows
# Writing to disk after 186352600000 rows
# Writing to disk after 186352700000 rows
# Writing to disk after 186352800000 rows
# Writing to disk after 186352900000 rows
# Writing to disk after 186353000000 rows
# Writing to disk after 186353100000 rows
# Writing to disk after 186353200000 rows
# Writing to disk after 186353300000 rows
# Writing to disk after 186353400000 rows
# Writing to disk after 186353500000 rows
# Writing to disk after 186353600000 rows
# Writing to disk after 186353700000 rows
# Writing to disk after 186353800000 rows
# Writing to disk after 186353900000 rows
# Writing to disk after 186354000000 rows
# Writing to disk after 186354100000 rows
# Writing to disk after 186354200000 rows
# Writing to disk after 186354300000 rows
# Writing to disk after 186354400000 rows
# Writing to disk after 186354500000 rows
# Writing to disk after 186354600000 rows
# Writing to disk after 186354700000 rows
# Writing to disk after 186354800000 rows
# Writing to disk after 186354900000 rows
# Writing to disk after 186355000000 rows
# Writing to disk after 186355100000 rows
# Writing to disk after 186355200000 rows
# Writing to disk after 186355300000 rows
# Writing to disk after 186355400000 rows
# Writing to disk after 186355500000 rows
# Writing to disk after 186355600000 rows
# Writing to disk after 186355700000 rows
# Writing to disk after 186355800000 rows
# Writing to disk after 186355900000 rows
# Writing to disk after 186356000000 rows
# Writing to disk after 186356100000 rows
# Writing to disk after 186356200000 rows
# Writing to disk after 186356300000 rows
# Writing to disk after 186356400000 rows
# Writing to disk after 186356500000 rows
# Writing to disk after 186356600000 rows
# Writing to disk after 186356700000 rows
# Writing to disk after 186356800000 rows
# Writing to disk after 186356900000 rows
# Writing to disk after 186357000000 rows
# Writing to disk after 186357100000 rows
# Writing to disk after 186357200000 rows
# Writing to disk after 186357300000 rows
# Writing to disk after 186357400000 rows
# Writing to disk after 186357500000 rows
# Writing to disk after 186357600000 rows
# Writing to disk after 186357700000 rows
# Writing to disk after 186357800000 rows
# Writing to disk after 186357900000 rows
# Writing to disk after 186358000000 rows
# Writing to disk after 186358100000 rows
# Writing to disk after 186358200000 rows
# Writing to disk after 186358300000 rows
# Writing to disk after 186358400000 rows
# Writing to disk after 186358500000 rows
# Writing to disk after 186358600000 rows
# Writing to disk after 186358700000 rows
# Writing to disk after 186358800000 rows
# Writing to disk after 186358900000 rows
# Writing to disk after 186359000000 rows
# Writing to disk after 186359100000 rows
# Writing to disk after 186359200000 rows
# Writing to disk after 186359300000 rows
# Writing to disk after 186359400000 rows
# Writing to disk after 186359500000 rows
# Writing to disk after 186359600000 rows
# Writing to disk after 186359700000 rows
# Writing to disk after 186359800000 rows
# Writing to disk after 186359900000 rows
# Writing to disk after 186360000000 rows
# Writing to disk after 186360100000 rows
# Writing to disk after 186360200000 rows
# Writing to disk after 186360300000 rows
# Writing to disk after 186360400000 rows
# Writing to disk after 186360500000 rows
# Writing to disk after 186360600000 rows
# Writing to disk after 186360700000 rows
# Writing to disk after 186360800000 rows
# Writing to disk after 186360900000 rows
# Writing to disk after 186361000000 rows
# Writing to disk after 186361100000 rows
# Writing to disk after 186361200000 rows
# Writing to disk after 186361300000 rows
# Writing to disk after 186361400000 rows
# Writing to disk after 186361500000 rows
# Writing to disk after 186361600000 rows
# Writing to disk after 186361700000 rows
# Writing to disk after 186361800000 rows
# Writing to disk after 186361900000 rows
# Writing to disk after 186362000000 rows
# Writing to disk after 186362100000 rows
# Writing to disk after 186362200000 rows
# Writing to disk after 186362300000 rows
# Writing to disk after 186362400000 rows
# Writing to disk after 186362500000 rows
# Writing to disk after 186362600000 rows
# Writing to disk after 186362700000 rows
# Writing to disk after 186362800000 rows
# Writing to disk after 186362900000 rows
# Writing to disk after 186363000000 rows
# Writing to disk after 186363100000 rows
# Writing to disk after 186363200000 rows
# Writing to disk after 186363300000 rows
# Writing to disk after 186363400000 rows
# Writing to disk after 186363500000 rows
# Writing to disk after 186363600000 rows
# Writing to disk after 186363700000 rows
# Writing to disk after 186363800000 rows
# Writing to disk after 186363900000 rows
# Writing to disk after 186364000000 rows
# Writing to disk after 186364100000 rows
# Writing to disk after 186364200000 rows
# Writing to disk after 186364300000 rows
# Writing to disk after 186364400000 rows
# Writing to disk after 186364500000 rows
# Writing to disk after 186364600000 rows
# Writing to disk after 186364700000 rows
# Writing to disk after 186364800000 rows
# Writing to disk after 186364900000 rows
# Writing to disk after 186365000000 rows
# Writing to disk after 186365100000 rows
# Writing to disk after 186365200000 rows
# Writing to disk after 186365300000 rows
# Writing to disk after 186365400000 rows
# Writing to disk after 186365500000 rows
# Writing to disk after 186365600000 rows
# Writing to disk after 186365700000 rows
# Writing to disk after 186365800000 rows
# Writing to disk after 186365900000 rows
# Writing to disk after 186366000000 rows
# Writing to disk after 186366100000 rows
# Writing to disk after 186366200000 rows
# Writing to disk after 186366300000 rows
# Writing to disk after 186366400000 rows
# Writing to disk after 186366500000 rows
# Writing to disk after 186366600000 rows
# Writing to disk after 186366700000 rows
# Writing to disk after 186366800000 rows
# Writing to disk after 186366900000 rows
# Writing to disk after 186367000000 rows
# Writing to disk after 186367100000 rows
# Writing to disk after 186367200000 rows
# Writing to disk after 186367300000 rows
# Writing to disk after 186367400000 rows
# Writing to disk after 186367500000 rows
# Writing to disk after 186367600000 rows
# Writing to disk after 186367700000 rows
# Writing to disk after 186367800000 rows
# Writing to disk after 186367900000 rows
# Writing to disk after 186368000000 rows
# Writing to disk after 186368100000 rows
# Writing to disk after 186368200000 rows
# Writing to disk after 186368300000 rows
# Writing to disk after 186368400000 rows
# Writing to disk after 186368500000 rows
# Writing to disk after 186368600000 rows
# Writing to disk after 186368700000 rows
# Writing to disk after 186368800000 rows
# Writing to disk after 186368900000 rows
# Writing to disk after 186369000000 rows
# Writing to disk after 186369100000 rows
# Writing to disk after 186369200000 rows
# Writing to disk after 186369300000 rows
# Writing to disk after 186369400000 rows
# Writing to disk after 186369500000 rows
# Writing to disk after 186369600000 rows
# Writing to disk after 186369700000 rows
# Writing to disk after 186369800000 rows
# Writing to disk after 186369900000 rows
# Writing to disk after 186370000000 rows
# Writing to disk after 186370100000 rows
# Writing to disk after 186370200000 rows
# Writing to disk after 186370300000 rows
# Writing to disk after 186370400000 rows
# Writing to disk after 186370500000 rows
# Writing to disk after 186370600000 rows
# Writing to disk after 186370700000 rows
# Writing to disk after 186370800000 rows
# Writing to disk after 186370900000 rows
# Writing to disk after 186371000000 rows
# Writing to disk after 186371100000 rows
# Writing to disk after 186371200000 rows
# Writing to disk after 186371300000 rows
# Writing to disk after 186371400000 rows
# Writing to disk after 186371500000 rows
# Writing to disk after 186371600000 rows
# Writing to disk after 186371700000 rows
# Writing to disk after 186371800000 rows
# Writing to disk after 186371900000 rows
# Writing to disk after 186372000000 rows
# Writing to disk after 186372100000 rows
# Writing to disk after 186372200000 rows
# Writing to disk after 186372300000 rows
# Writing to disk after 186372400000 rows
# Writing to disk after 186372500000 rows
# Writing to disk after 186372600000 rows
# Writing to disk after 186372700000 rows
# Writing to disk after 186372800000 rows
# Writing to disk after 186372900000 rows
# Writing to disk after 186373000000 rows
# Writing to disk after 186373100000 rows
# Writing to disk after 186373200000 rows
# Writing to disk after 186373300000 rows
# Writing to disk after 186373400000 rows
# Writing to disk after 186373500000 rows
# Writing to disk after 186373600000 rows
# Writing to disk after 186373700000 rows
# Writing to disk after 186373800000 rows
# Writing to disk after 186373900000 rows
# Writing to disk after 186374000000 rows
# Writing to disk after 186374100000 rows
# Writing to disk after 186374200000 rows
# Writing to disk after 186374300000 rows
# Writing to disk after 186374400000 rows
# Writing to disk after 186374500000 rows
# Writing to disk after 186374600000 rows
# Writing to disk after 186374700000 rows
# Writing to disk after 186374800000 rows
# Writing to disk after 186374900000 rows
# Writing to disk after 186375000000 rows
# Writing to disk after 186375100000 rows
# Writing to disk after 186375200000 rows
# Writing to disk after 186375300000 rows
# Writing to disk after 186375400000 rows
# Writing to disk after 186375500000 rows
# Writing to disk after 186375600000 rows
# Writing to disk after 186375700000 rows
# Writing to disk after 186375800000 rows
# Writing to disk after 186375900000 rows
# Writing to disk after 186376000000 rows
# Writing to disk after 186376100000 rows
# Writing to disk after 186376200000 rows
# Writing to disk after 186376300000 rows
# Writing to disk after 186376400000 rows
# Writing to disk after 186376500000 rows
# Writing to disk after 186376600000 rows
# Writing to disk after 186376700000 rows
# Writing to disk after 186376800000 rows
# Writing to disk after 186376900000 rows
# Writing to disk after 186377000000 rows
# Writing to disk after 186377100000 rows
# Writing to disk after 186377200000 rows
# Writing to disk after 186377300000 rows
# Writing to disk after 186377400000 rows
# Writing to disk after 186377500000 rows
# Writing to disk after 186377600000 rows
# Writing to disk after 186377700000 rows
# Writing to disk after 186377800000 rows
# Writing to disk after 186377900000 rows
# Writing to disk after 186378000000 rows
# Writing to disk after 186378100000 rows
# Writing to disk after 186378200000 rows
# Writing to disk after 186378300000 rows
# Writing to disk after 186378400000 rows
# Writing to disk after 186378500000 rows
# Writing to disk after 186378600000 rows
# Writing to disk after 186378700000 rows
# Writing to disk after 186378800000 rows
# Writing to disk after 186378900000 rows
# Writing to disk after 186379000000 rows
# Writing to disk after 186379100000 rows
# Writing to disk after 186379200000 rows
# Writing to disk after 186379300000 rows
# Writing to disk after 186379400000 rows
# Writing to disk after 186379500000 rows
# Writing to disk after 186379600000 rows
# Writing to disk after 186379700000 rows
# Writing to disk after 186379800000 rows
# Writing to disk after 186379900000 rows
# Writing to disk after 186380000000 rows
# Writing to disk after 186380100000 rows
# Writing to disk after 186380200000 rows
# Writing to disk after 186380300000 rows
# Writing to disk after 186380400000 rows
# Writing to disk after 186380500000 rows
# Writing to disk after 186380600000 rows
# Writing to disk after 186380700000 rows
# Writing to disk after 186380800000 rows
# Writing to disk after 186380900000 rows
# Writing to disk after 186381000000 rows
# Writing to disk after 186381100000 rows
# Writing to disk after 186381200000 rows
# Writing to disk after 186381300000 rows
# Writing to disk after 186381400000 rows
# Writing to disk after 186381500000 rows
# Writing to disk after 186381600000 rows
# Writing to disk after 186381700000 rows
# Writing to disk after 186381800000 rows
# Writing to disk after 186381900000 rows
# Writing to disk after 186382000000 rows
# Writing to disk after 186382100000 rows
# Writing to disk after 186382200000 rows
# Writing to disk after 186382300000 rows
# Writing to disk after 186382400000 rows
# Writing to disk after 186382500000 rows
# Writing to disk after 186382600000 rows
# Writing to disk after 186382700000 rows
# Writing to disk after 186382800000 rows
# Writing to disk after 186382900000 rows
# Writing to disk after 186383000000 rows
# Writing to disk after 186383100000 rows
# Writing to disk after 186383200000 rows
# Writing to disk after 186383300000 rows
# Writing to disk after 186383400000 rows
# Writing to disk after 186383500000 rows
# Writing to disk after 186383600000 rows
# Writing to disk after 186383700000 rows
# Writing to disk after 186383800000 rows
# Writing to disk after 186383900000 rows
# Writing to disk after 186384000000 rows
# Writing to disk after 186384100000 rows
# Writing to disk after 186384200000 rows
# Writing to disk after 186384300000 rows
# Writing to disk after 186384400000 rows
# Writing to disk after 186384500000 rows
# Writing to disk after 186384600000 rows
# Writing to disk after 186384700000 rows
# Writing to disk after 186384800000 rows
# Writing to disk after 186384900000 rows
# Writing to disk after 186385000000 rows
# Writing to disk after 186385100000 rows
# Writing to disk after 186385200000 rows
# Writing to disk after 186385300000 rows
# Writing to disk after 186385400000 rows
# Writing to disk after 186385500000 rows
# Writing to disk after 186385600000 rows
# Writing to disk after 186385700000 rows
# Writing to disk after 186385800000 rows
# Writing to disk after 186385900000 rows
# Writing to disk after 186386000000 rows
# Writing to disk after 186386100000 rows
# Writing to disk after 186386200000 rows
# Writing to disk after 186386300000 rows
# Writing to disk after 186386400000 rows
# Writing to disk after 186386500000 rows
# Writing to disk after 186386600000 rows
# Writing to disk after 186386700000 rows
# Writing to disk after 186386800000 rows
# Writing to disk after 186386900000 rows
# Writing to disk after 186387000000 rows
# Writing to disk after 186387100000 rows
# Writing to disk after 186387200000 rows
# Writing to disk after 186387300000 rows
# Writing to disk after 186387400000 rows
# Writing to disk after 186387500000 rows
# Writing to disk after 186387600000 rows
# Writing to disk after 186387700000 rows
# Writing to disk after 186387800000 rows
# Writing to disk after 186387900000 rows
# Writing to disk after 186388000000 rows
# Writing to disk after 186388100000 rows
# Writing to disk after 186388200000 rows
# Writing to disk after 186388300000 rows
# Writing to disk after 186388400000 rows
# Writing to disk after 186388500000 rows
# Writing to disk after 186388600000 rows
# Writing to disk after 186388700000 rows
# Writing to disk after 186388800000 rows
# Writing to disk after 186388900000 rows
# Writing to disk after 186389000000 rows
# Writing to disk after 186389100000 rows
# Writing to disk after 186389200000 rows
# Writing to disk after 186389300000 rows
# Writing to disk after 186389400000 rows
# Writing to disk after 186389500000 rows
# Writing to disk after 186389600000 rows
# Writing to disk after 186389700000 rows
# Writing to disk after 186389800000 rows
# Writing to disk after 186389900000 rows
# Writing to disk after 186390000000 rows
# Writing to disk after 186390100000 rows
# Writing to disk after 186390200000 rows
# Writing to disk after 186390300000 rows
# Writing to disk after 186390400000 rows
# Writing to disk after 186390500000 rows
# Writing to disk after 186390600000 rows
# Writing to disk after 186390700000 rows
# Writing to disk after 186390800000 rows
# Writing to disk after 186390900000 rows
# Writing to disk after 186391000000 rows
# Writing to disk after 186391100000 rows
# Writing to disk after 186391200000 rows
# Writing to disk after 186391300000 rows
# Writing to disk after 186391400000 rows
# Writing to disk after 186391500000 rows
# Writing to disk after 186391600000 rows
# Writing to disk after 186391700000 rows
# Writing to disk after 186391800000 rows
# Writing to disk after 186391900000 rows
# Writing to disk after 186392000000 rows
# Writing to disk after 186392100000 rows
# Writing to disk after 186392200000 rows
# Writing to disk after 186392300000 rows
# Writing to disk after 186392400000 rows
# Writing to disk after 186392500000 rows
# Writing to disk after 186392600000 rows
# Writing to disk after 186392700000 rows
# Writing to disk after 186392800000 rows
# Writing to disk after 186392900000 rows
# Writing to disk after 186393000000 rows
# Writing to disk after 186393100000 rows
# Writing to disk after 186393200000 rows
# Writing to disk after 186393300000 rows
# Writing to disk after 186393400000 rows
# Writing to disk after 186393500000 rows
# Writing to disk after 186393600000 rows
# Writing to disk after 186393700000 rows
# Writing to disk after 186393800000 rows
# Writing to disk after 186393900000 rows
# Writing to disk after 186394000000 rows
# Writing to disk after 186394100000 rows
# Writing to disk after 186394200000 rows
# Writing to disk after 186394300000 rows
# Writing to disk after 186394400000 rows
# Writing to disk after 186394500000 rows
# Writing to disk after 186394600000 rows
# Writing to disk after 186394700000 rows
# Writing to disk after 186394800000 rows
# Writing to disk after 186394900000 rows
# Writing to disk after 186395000000 rows
# Writing to disk after 186395100000 rows
# Writing to disk after 186395200000 rows
# Writing to disk after 186395300000 rows
# Writing to disk after 186395400000 rows
# Writing to disk after 186395500000 rows
# Writing to disk after 186395600000 rows
# Writing to disk after 186395700000 rows
# Writing to disk after 186395800000 rows
# Writing to disk after 186395900000 rows
# Writing to disk after 186396000000 rows
# Writing to disk after 186396100000 rows
# Writing to disk after 186396200000 rows
# Writing to disk after 186396300000 rows
# Writing to disk after 186396400000 rows
# Writing to disk after 186396500000 rows
# Writing to disk after 186396600000 rows
# Writing to disk after 186396700000 rows
# Writing to disk after 186396800000 rows
# Writing to disk after 186396900000 rows
# Writing to disk after 186397000000 rows
# Writing to disk after 186397100000 rows
# Writing to disk after 186397200000 rows
# Writing to disk after 186397300000 rows
# Writing to disk after 186397400000 rows
# Writing to disk after 186397500000 rows
# Writing to disk after 186397600000 rows
# Writing to disk after 186397700000 rows
# Writing to disk after 186397800000 rows
# Writing to disk after 186397900000 rows
# Writing to disk after 186398000000 rows
# Writing to disk after 186398100000 rows
# Writing to disk after 186398200000 rows
# Writing to disk after 186398300000 rows
# Writing to disk after 186398400000 rows
# Writing to disk after 186398500000 rows
# Writing to disk after 186398600000 rows
# Writing to disk after 186398700000 rows
# Writing to disk after 186398800000 rows
# Writing to disk after 186398900000 rows
# Writing to disk after 186399000000 rows
# Writing to disk after 186399100000 rows
# Writing to disk after 186399200000 rows
# Writing to disk after 186399300000 rows
# Writing to disk after 186399400000 rows
# Writing to disk after 186399500000 rows
# Writing to disk after 186399600000 rows
# Writing to disk after 186399700000 rows
# Writing to disk after 186399800000 rows
# Writing to disk after 186399900000 rows
# Writing to disk after 186400000000 rows
# Writing to disk after 186400100000 rows
# Writing to disk after 186400200000 rows
# Writing to disk after 186400300000 rows
# Writing to disk after 186400400000 rows
# Writing to disk after 186400500000 rows
# Writing to disk after 186400600000 rows
# Writing to disk after 186400700000 rows
# Writing to disk after 186400800000 rows
# Writing to disk after 186400900000 rows
# Writing to disk after 186401000000 rows
# Writing to disk after 186401100000 rows
# Writing to disk after 186401200000 rows
# Writing to disk after 186401300000 rows
# Writing to disk after 186401400000 rows
# Writing to disk after 186401500000 rows
# Writing to disk after 186401600000 rows
# Writing to disk after 186401700000 rows
# Writing to disk after 186401800000 rows
# Writing to disk after 186401900000 rows
# Writing to disk after 186402000000 rows
# Writing to disk after 186402100000 rows
# Writing to disk after 186402200000 rows
# Writing to disk after 186402300000 rows
# Writing to disk after 186402400000 rows
# Writing to disk after 186402500000 rows
# Writing to disk after 186402600000 rows
# Writing to disk after 186402700000 rows
# Writing to disk after 186402800000 rows
# Writing to disk after 186402900000 rows
# Writing to disk after 186403000000 rows
# Writing to disk after 186403100000 rows
# Writing to disk after 186403200000 rows
# Writing to disk after 186403300000 rows
# Writing to disk after 186403400000 rows
# Writing to disk after 186403500000 rows
# Writing to disk after 186403600000 rows
# Writing to disk after 186403700000 rows
# Writing to disk after 186403800000 rows
# Writing to disk after 186403900000 rows
# Writing to disk after 186404000000 rows
# Writing to disk after 186404100000 rows
# Writing to disk after 186404200000 rows
# Writing to disk after 186404300000 rows
# Writing to disk after 186404400000 rows
# Writing to disk after 186404500000 rows
# Writing to disk after 186404600000 rows
# Writing to disk after 186404700000 rows
# Writing to disk after 186404800000 rows
# Writing to disk after 186404900000 rows
# Writing to disk after 186405000000 rows
# Writing to disk after 186405100000 rows
# Writing to disk after 186405200000 rows
# Writing to disk after 186405300000 rows
# Writing to disk after 186405400000 rows
# Writing to disk after 186405500000 rows
# Writing to disk after 186405600000 rows
# Writing to disk after 186405700000 rows
# Writing to disk after 186405800000 rows
# Writing to disk after 186405900000 rows
# Writing to disk after 186406000000 rows
# Writing to disk after 186406100000 rows
# Writing to disk after 186406200000 rows
# Writing to disk after 186406300000 rows
# Writing to disk after 186406400000 rows
# Writing to disk after 186406500000 rows
# Writing to disk after 186406600000 rows
# Writing to disk after 186406700000 rows
# Writing to disk after 186406800000 rows
# Writing to disk after 186406900000 rows
# Writing to disk after 186407000000 rows
# Writing to disk after 186407100000 rows
# Writing to disk after 186407200000 rows
# Writing to disk after 186407300000 rows
# Writing to disk after 186407400000 rows
# Writing to disk after 186407500000 rows
# Writing to disk after 186407600000 rows
# Writing to disk after 186407700000 rows
# Writing to disk after 186407800000 rows
# Writing to disk after 186407900000 rows
# Writing to disk after 186408000000 rows
# Writing to disk after 186408100000 rows
# Writing to disk after 186408200000 rows
# Writing to disk after 186408300000 rows
# Writing to disk after 186408400000 rows
# Writing to disk after 186408500000 rows
# Writing to disk after 186408600000 rows
# Writing to disk after 186408700000 rows
# Writing to disk after 186408800000 rows
# Writing to disk after 186408900000 rows
# Writing to disk after 186409000000 rows
# Writing to disk after 186409100000 rows
# Writing to disk after 186409200000 rows
# Writing to disk after 186409300000 rows
# Writing to disk after 186409400000 rows
# Writing to disk after 186409500000 rows
# Writing to disk after 186409600000 rows
# Writing to disk after 186409700000 rows
# Writing to disk after 186409800000 rows
# Writing to disk after 186409900000 rows
# Writing to disk after 186410000000 rows
# Writing to disk after 186410100000 rows
# Writing to disk after 186410200000 rows
# Writing to disk after 186410300000 rows
# Writing to disk after 186410400000 rows
# Writing to disk after 186410500000 rows
# Writing to disk after 186410600000 rows
# Writing to disk after 186410700000 rows
# Writing to disk after 186410800000 rows
# Writing to disk after 186410900000 rows
# Writing to disk after 186411000000 rows
# Writing to disk after 186411100000 rows
# Writing to disk after 186411200000 rows
# Writing to disk after 186411300000 rows
# Writing to disk after 186411400000 rows
# Writing to disk after 186411500000 rows
# Writing to disk after 186411600000 rows
# Writing to disk after 186411700000 rows
# Writing to disk after 186411800000 rows
# Writing to disk after 186411900000 rows
# Writing to disk after 186412000000 rows
# Writing to disk after 186412100000 rows
# Writing to disk after 186412200000 rows
# Writing to disk after 186412300000 rows
# Writing to disk after 186412400000 rows
# Writing to disk after 186412500000 rows
# Writing to disk after 186412600000 rows
# Writing to disk after 186412700000 rows
# Writing to disk after 186412800000 rows
# Writing to disk after 186412900000 rows
# Writing to disk after 186413000000 rows
# Writing to disk after 186413100000 rows
# Writing to disk after 186413200000 rows
# Writing to disk after 186413300000 rows
# Writing to disk after 186413400000 rows
# Writing to disk after 186413500000 rows
# Writing to disk after 186413600000 rows
# Writing to disk after 186413700000 rows
# Writing to disk after 186413800000 rows
# Writing to disk after 186413900000 rows
# Writing to disk after 186414000000 rows
# Writing to disk after 186414100000 rows
# Writing to disk after 186414200000 rows
# Writing to disk after 186414300000 rows
# Writing to disk after 186414400000 rows
# Writing to disk after 186414500000 rows
# Writing to disk after 186414600000 rows
# Writing to disk after 186414700000 rows
# Writing to disk after 186414800000 rows
# Writing to disk after 186414900000 rows
# Writing to disk after 186415000000 rows
# Writing to disk after 186415100000 rows
# Writing to disk after 186415200000 rows
# Writing to disk after 186415300000 rows
# Writing to disk after 186415400000 rows
# Writing to disk after 186415500000 rows
# Writing to disk after 186415600000 rows
# Writing to disk after 186415700000 rows
# Writing to disk after 186415800000 rows
# Writing to disk after 186415900000 rows
# Writing to disk after 186416000000 rows
# Writing to disk after 186416100000 rows
# Writing to disk after 186416200000 rows
# Writing to disk after 186416300000 rows
# Writing to disk after 186416400000 rows
# Writing to disk after 186416500000 rows
# Writing to disk after 186416600000 rows
# Writing to disk after 186416700000 rows
# Writing to disk after 186416800000 rows
# Writing to disk after 186416900000 rows
# Writing to disk after 186417000000 rows
# Writing to disk after 186417100000 rows
# Writing to disk after 186417200000 rows
# Writing to disk after 186417300000 rows
# Writing to disk after 186417400000 rows
# Writing to disk after 186417500000 rows
# Writing to disk after 186417600000 rows
# Writing to disk after 186417700000 rows
# Writing to disk after 186417800000 rows
# Writing to disk after 186417900000 rows
# Writing to disk after 186418000000 rows
# Writing to disk after 186418100000 rows
# Writing to disk after 186418200000 rows
# Writing to disk after 186418300000 rows
# Writing to disk after 186418400000 rows
# Writing to disk after 186418500000 rows
# Writing to disk after 186418600000 rows
# Writing to disk after 186418700000 rows
# Writing to disk after 186418800000 rows
# Writing to disk after 186418900000 rows
# Writing to disk after 186419000000 rows
# Writing to disk after 186419100000 rows
# Writing to disk after 186419200000 rows
# Writing to disk after 186419300000 rows
# Writing to disk after 186419400000 rows
# Writing to disk after 186419500000 rows
# Writing to disk after 186419600000 rows
# Writing to disk after 186419700000 rows
# Writing to disk after 186419800000 rows
# Writing to disk after 186419900000 rows
# Writing to disk after 186420000000 rows
# Writing to disk after 186420100000 rows
# Writing to disk after 186420200000 rows
# Writing to disk after 186420300000 rows
# Writing to disk after 186420400000 rows
# Writing to disk after 186420500000 rows
# Writing to disk after 186420600000 rows
# Writing to disk after 186420700000 rows
# Writing to disk after 186420800000 rows
# Writing to disk after 186420900000 rows
# Writing to disk after 186421000000 rows
# Writing to disk after 186421100000 rows
# Writing to disk after 186421200000 rows
# Writing to disk after 186421300000 rows
# Writing to disk after 186421400000 rows
# Writing to disk after 186421500000 rows
# Writing to disk after 186421600000 rows
# Writing to disk after 186421700000 rows
# Writing to disk after 186421800000 rows
# Writing to disk after 186421900000 rows
# Writing to disk after 186422000000 rows
# Writing to disk after 186422100000 rows
# Writing to disk after 186422200000 rows
# Writing to disk after 186422300000 rows
# Writing to disk after 186422400000 rows
# Writing to disk after 186422500000 rows
# Writing to disk after 186422600000 rows
# Writing to disk after 186422700000 rows
# Writing to disk after 186422800000 rows
# Writing to disk after 186422900000 rows
# Writing to disk after 186423000000 rows
# Writing to disk after 186423100000 rows
# Writing to disk after 186423200000 rows
# Writing to disk after 186423300000 rows
# Writing to disk after 186423400000 rows
# Writing to disk after 186423500000 rows
# Writing to disk after 186423600000 rows
# Writing to disk after 186423700000 rows
# Writing to disk after 186423800000 rows
# Writing to disk after 186423900000 rows
# Writing to disk after 186424000000 rows
# Writing to disk after 186424100000 rows
# Writing to disk after 186424200000 rows
# Writing to disk after 186424300000 rows
# Writing to disk after 186424400000 rows
# Writing to disk after 186424500000 rows
# Writing to disk after 186424600000 rows
# Writing to disk after 186424700000 rows
# Writing to disk after 186424800000 rows
# Writing to disk after 186424900000 rows
# Writing to disk after 186425000000 rows
# Writing to disk after 186425100000 rows
# Writing to disk after 186425200000 rows
# Writing to disk after 186425300000 rows
# Writing to disk after 186425400000 rows
# Writing to disk after 186425500000 rows
# Writing to disk after 186425600000 rows
# Writing to disk after 186425700000 rows
# Writing to disk after 186425800000 rows
# Writing to disk after 186425900000 rows
# Writing to disk after 186426000000 rows
# Writing to disk after 186426100000 rows
# Writing to disk after 186426200000 rows
# Writing to disk after 186426300000 rows
# Writing to disk after 186426400000 rows
# Writing to disk after 186426500000 rows
# Writing to disk after 186426600000 rows
# Writing to disk after 186426700000 rows
# Writing to disk after 186426800000 rows
# Writing to disk after 186426900000 rows
# Writing to disk after 186427000000 rows
# Writing to disk after 186427100000 rows
# Writing to disk after 186427200000 rows
# Writing to disk after 186427300000 rows
# Writing to disk after 186427400000 rows
# Writing to disk after 186427500000 rows
# Writing to disk after 186427600000 rows
# Writing to disk after 186427700000 rows
# Writing to disk after 186427800000 rows
# Writing to disk after 186427900000 rows
# Writing to disk after 186428000000 rows
# Writing to disk after 186428100000 rows
# Writing to disk after 186428200000 rows
# Writing to disk after 186428300000 rows
# Writing to disk after 186428400000 rows
# Writing to disk after 186428500000 rows
# Writing to disk after 186428600000 rows
# Writing to disk after 186428700000 rows
# Writing to disk after 186428800000 rows
# Writing to disk after 186428900000 rows
# Writing to disk after 186429000000 rows
# Writing to disk after 186429100000 rows
# Writing to disk after 186429200000 rows
# Writing to disk after 186429300000 rows
# Writing to disk after 186429400000 rows
# Writing to disk after 186429500000 rows
# Writing to disk after 186429600000 rows
# Writing to disk after 186429700000 rows
# Writing to disk after 186429800000 rows
# Writing to disk after 186429900000 rows
# Writing to disk after 186430000000 rows
# Writing to disk after 186430100000 rows
# Writing to disk after 186430200000 rows
# Writing to disk after 186430300000 rows
# Writing to disk after 186430400000 rows
# Writing to disk after 186430500000 rows
# Writing to disk after 186430600000 rows
# Writing to disk after 186430700000 rows
# Writing to disk after 186430800000 rows
# Writing to disk after 186430900000 rows
# Writing to disk after 186431000000 rows
# Writing to disk after 186431100000 rows
# Writing to disk after 186431200000 rows
# Writing to disk after 186431300000 rows
# Writing to disk after 186431400000 rows
# Writing to disk after 186431500000 rows
# Writing to disk after 186431600000 rows
# Writing to disk after 186431700000 rows
# Writing to disk after 186431800000 rows
# Writing to disk after 186431900000 rows
# Writing to disk after 186432000000 rows
# Writing to disk after 186432100000 rows
# Writing to disk after 186432200000 rows
# Writing to disk after 186432300000 rows
# Writing to disk after 186432400000 rows
# Writing to disk after 186432500000 rows
# Writing to disk after 186432600000 rows
# Writing to disk after 186432700000 rows
# Writing to disk after 186432800000 rows
# Writing to disk after 186432900000 rows
# Writing to disk after 186433000000 rows
# Writing to disk after 186433100000 rows
# Writing to disk after 186433200000 rows
# Writing to disk after 186433300000 rows
# Writing to disk after 186433400000 rows
# Writing to disk after 186433500000 rows
# Writing to disk after 186433600000 rows
# Writing to disk after 186433700000 rows
# Writing to disk after 186433800000 rows
# Writing to disk after 186433900000 rows
# Writing to disk after 186434000000 rows
# Writing to disk after 186434100000 rows
# Writing to disk after 186434200000 rows
# Writing to disk after 186434300000 rows
# Writing to disk after 186434400000 rows
# Writing to disk after 186434500000 rows
# Writing to disk after 186434600000 rows
# Writing to disk after 186434700000 rows
# Writing to disk after 186434800000 rows
# Writing to disk after 186434900000 rows
# Writing to disk after 186435000000 rows
# Writing to disk after 186435100000 rows
# Writing to disk after 186435200000 rows
# Writing to disk after 186435300000 rows
# Writing to disk after 186435400000 rows
# Writing to disk after 186435500000 rows
# Writing to disk after 186435600000 rows
# Writing to disk after 186435700000 rows
# Writing to disk after 186435800000 rows
# Writing to disk after 186435900000 rows
# Writing to disk after 186436000000 rows
# Writing to disk after 186436100000 rows
# Writing to disk after 186436200000 rows
# Writing to disk after 186436300000 rows
# Writing to disk after 186436400000 rows
# Writing to disk after 186436500000 rows
# Writing to disk after 186436600000 rows
# Writing to disk after 186436700000 rows
# Writing to disk after 186436800000 rows
# Writing to disk after 186436900000 rows
# Writing to disk after 186437000000 rows
# Writing to disk after 186437100000 rows
# Writing to disk after 186437200000 rows
# Writing to disk after 186437300000 rows
# Writing to disk after 186437400000 rows
# Writing to disk after 186437500000 rows
# Writing to disk after 186437600000 rows
# Writing to disk after 186437700000 rows
# Writing to disk after 186437800000 rows
# Writing to disk after 186437900000 rows
# Writing to disk after 186438000000 rows
# Writing to disk after 186438100000 rows
# Writing to disk after 186438200000 rows
# Writing to disk after 186438300000 rows
# Writing to disk after 186438400000 rows
# Writing to disk after 186438500000 rows
# Writing to disk after 186438600000 rows
# Writing to disk after 186438700000 rows
# Writing to disk after 186438800000 rows
# Writing to disk after 186438900000 rows
# Writing to disk after 186439000000 rows
# Writing to disk after 186439100000 rows
# Writing to disk after 186439200000 rows
# Writing to disk after 186439300000 rows
# Writing to disk after 186439400000 rows
# Writing to disk after 186439500000 rows
# Writing to disk after 186439600000 rows
# Writing to disk after 186439700000 rows
# Writing to disk after 186439800000 rows
# Writing to disk after 186439900000 rows
# Writing to disk after 186440000000 rows
# Writing to disk after 186440100000 rows
# Writing to disk after 186440200000 rows
# Writing to disk after 186440300000 rows
# Writing to disk after 186440400000 rows
# Writing to disk after 186440500000 rows
# Writing to disk after 186440600000 rows
# Writing to disk after 186440700000 rows
# ...
# Writing to disk after 186781000000 rows
# Writing to disk after 186781100000 rows
# Writing to disk after 186781200000 rows
# Writing to disk after 186781300000 rows
# Writing to disk after 186781400000 rows
# Writing to disk after 186781500000 rows
# Writing to disk after 186781600000 rows
# Writing to disk after 186781700000 rows
# Writing to disk after 186781800000 rows
# Writing to disk after 186781900000 rows
# Writing to disk after 186782000000 rows
# Writing to disk after 186782100000 rows
# Writing to disk after 186782200000 rows
# Writing to disk after 186782300000 rows
# Writing to disk after 186782400000 rows
# Writing to disk after 186782500000 rows
# Writing to disk after 186782600000 rows
# Writing to disk after 186782700000 rows
# Writing to disk after 186782800000 rows
# Writing to disk after 186782900000 rows
# Writing to disk after 186783000000 rows
# Writing to disk after 186783100000 rows
# Writing to disk after 186783200000 rows
# Writing to disk after 186783300000 rows
# Writing to disk after 186783400000 rows
# Writing to disk after 186783500000 rows
# Writing to disk after 186783600000 rows
# Writing to disk after 186783700000 rows
# Writing to disk after 186783800000 rows
# Writing to disk after 186783900000 rows
# Writing to disk after 186784000000 rows
# Writing to disk after 186784100000 rows
# Writing to disk after 186784200000 rows
# Writing to disk after 186784300000 rows
# Writing to disk after 186784400000 rows
# Writing to disk after 186784500000 rows
# Writing to disk after 186784600000 rows
# Writing to disk after 186784700000 rows
# Writing to disk after 186784800000 rows
# Writing to disk after 186784900000 rows
# Writing to disk after 186785000000 rows
# Writing to disk after 186785100000 rows
# Writing to disk after 186785200000 rows
# Writing to disk after 186785300000 rows
# Writing to disk after 186785400000 rows
# Writing to disk after 186785500000 rows
# Writing to disk after 186785600000 rows
# Writing to disk after 186785700000 rows
# Writing to disk after 186785800000 rows
# Writing to disk after 186785900000 rows
# Writing to disk after 186786000000 rows
# Writing to disk after 186786100000 rows
# Writing to disk after 186786200000 rows
# Writing to disk after 186786300000 rows
# Writing to disk after 186786400000 rows
# Writing to disk after 186786500000 rows
# Writing to disk after 186786600000 rows
# Writing to disk after 186786700000 rows
# Writing to disk after 186786800000 rows
# Writing to disk after 186786900000 rows
# Writing to disk after 186787000000 rows
# Writing to disk after 186787100000 rows
# Writing to disk after 186787200000 rows
# Writing to disk after 186787300000 rows
# Writing to disk after 186787400000 rows
# Writing to disk after 186787500000 rows
# Writing to disk after 186787600000 rows
# Writing to disk after 186787700000 rows
# Writing to disk after 186787800000 rows
# Writing to disk after 186787900000 rows
# Writing to disk after 186788000000 rows
# Writing to disk after 186788100000 rows
# Writing to disk after 186788200000 rows
# Writing to disk after 186788300000 rows
# Writing to disk after 186788400000 rows
# Writing to disk after 186788500000 rows
# Writing to disk after 186788600000 rows
# Writing to disk after 186788700000 rows
# Writing to disk after 186788800000 rows
# Writing to disk after 186788900000 rows
# Writing to disk after 186789000000 rows
# Writing to disk after 186789100000 rows
# Writing to disk after 186789200000 rows
# Writing to disk after 186789300000 rows
# Writing to disk after 186789400000 rows
# Writing to disk after 186789500000 rows
# Writing to disk after 186789600000 rows
# Writing to disk after 186789700000 rows
# Writing to disk after 186789800000 rows
# Writing to disk after 186789900000 rows
# Writing to disk after 186790000000 rows
# Writing to disk after 186790100000 rows
# Writing to disk after 186790200000 rows
# Writing to disk after 186790300000 rows
# Writing to disk after 186790400000 rows
# Writing to disk after 186790500000 rows
# Writing to disk after 186790600000 rows
# Writing to disk after 186790700000 rows
# Writing to disk after 186790800000 rows
# Writing to disk after 186790900000 rows
# Writing to disk after 186791000000 rows
# Writing to disk after 186791100000 rows
# Writing to disk after 186791200000 rows
# Writing to disk after 186791300000 rows
# Writing to disk after 186791400000 rows
# Writing to disk after 186791500000 rows
# Writing to disk after 186791600000 rows
# Writing to disk after 186791700000 rows
# Writing to disk after 186791800000 rows
# Writing to disk after 186791900000 rows
# Writing to disk after 186792000000 rows
# Writing to disk after 186792100000 rows
# Writing to disk after 186792200000 rows
# Writing to disk after 186792300000 rows
# Writing to disk after 186792400000 rows
# Writing to disk after 186792500000 rows
# Writing to disk after 186792600000 rows
# Writing to disk after 186792700000 rows
# Writing to disk after 186792800000 rows
# Writing to disk after 186792900000 rows
# Writing to disk after 186793000000 rows
# Writing to disk after 186793100000 rows
# Writing to disk after 186793200000 rows
# Writing to disk after 186793300000 rows
# Writing to disk after 186793400000 rows
# Writing to disk after 186793500000 rows
# Writing to disk after 186793600000 rows
# Writing to disk after 186793700000 rows
# Writing to disk after 186793800000 rows
# Writing to disk after 186793900000 rows
# Writing to disk after 186794000000 rows
# Writing to disk after 186794100000 rows
# Writing to disk after 186794200000 rows
# Writing to disk after 186794300000 rows
# Writing to disk after 186794400000 rows
# Writing to disk after 186794500000 rows
# Writing to disk after 186794600000 rows
# Writing to disk after 186794700000 rows
# Writing to disk after 186794800000 rows
# Writing to disk after 186794900000 rows
# Writing to disk after 186795000000 rows
# Writing to disk after 186795100000 rows
# Writing to disk after 186795200000 rows
# Writing to disk after 186795300000 rows
# Writing to disk after 186795400000 rows
# Writing to disk after 186795500000 rows
# Writing to disk after 186795600000 rows
# Writing to disk after 186795700000 rows
# Writing to disk after 186795800000 rows
# Writing to disk after 186795900000 rows
# Writing to disk after 186796000000 rows
# Writing to disk after 186796100000 rows
# Writing to disk after 186796200000 rows
# Writing to disk after 186796300000 rows
# Writing to disk after 186796400000 rows
# Writing to disk after 186796500000 rows
# Writing to disk after 186796600000 rows
# Writing to disk after 186796700000 rows
# Writing to disk after 186796800000 rows
# Writing to disk after 186796900000 rows
# Writing to disk after 186797000000 rows
# Writing to disk after 186797100000 rows
# Writing to disk after 186797200000 rows
# Writing to disk after 186797300000 rows
# Writing to disk after 186797400000 rows
# Writing to disk after 186797500000 rows
# Writing to disk after 186797600000 rows
# Writing to disk after 186797700000 rows
# Writing to disk after 186797800000 rows
# Writing to disk after 186797900000 rows
# Writing to disk after 186798000000 rows
# Writing to disk after 186798100000 rows
# Writing to disk after 186798200000 rows
# Writing to disk after 186798300000 rows
# Writing to disk after 186798400000 rows
# Writing to disk after 186798500000 rows
# Writing to disk after 186798600000 rows
# Writing to disk after 186798700000 rows
# Writing to disk after 186798800000 rows
# Writing to disk after 186798900000 rows
# Writing to disk after 186799000000 rows
# Writing to disk after 186799100000 rows
# Writing to disk after 186799200000 rows
# Writing to disk after 186799300000 rows
# Writing to disk after 186799400000 rows
# Writing to disk after 186799500000 rows
# Writing to disk after 186799600000 rows
# Writing to disk after 186799700000 rows
# Writing to disk after 186799800000 rows
# Writing to disk after 186799900000 rows
# Writing to disk after 186800000000 rows
# Writing to disk after 186800100000 rows
# Writing to disk after 186800200000 rows
# Writing to disk after 186800300000 rows
# Writing to disk after 186800400000 rows
# Writing to disk after 186800500000 rows
# Writing to disk after 186800600000 rows
# Writing to disk after 186800700000 rows
# Writing to disk after 186800800000 rows
# Writing to disk after 186800900000 rows
# Writing to disk after 186801000000 rows
# Writing to disk after 186801100000 rows
# Writing to disk after 186801200000 rows
# Writing to disk after 186801300000 rows
# Writing to disk after 186801400000 rows
# Writing to disk after 186801500000 rows
# Writing to disk after 186801600000 rows
# Writing to disk after 186801700000 rows
# Writing to disk after 186801800000 rows
# Writing to disk after 186801900000 rows
# Writing to disk after 186802000000 rows
# Writing to disk after 186802100000 rows
# Writing to disk after 186802200000 rows
# Writing to disk after 186802300000 rows
# Writing to disk after 186802400000 rows
# Writing to disk after 186802500000 rows
# Writing to disk after 186802600000 rows
# Writing to disk after 186802700000 rows
# Writing to disk after 186802800000 rows
# Writing to disk after 186802900000 rows
# Writing to disk after 186803000000 rows
# Writing to disk after 186803100000 rows
# Writing to disk after 186803200000 rows
# Writing to disk after 186803300000 rows
# Writing to disk after 186803400000 rows
# Writing to disk after 186803500000 rows
# Writing to disk after 186803600000 rows
# Writing to disk after 186803700000 rows
# Writing to disk after 186803800000 rows
# Writing to disk after 186803900000 rows
# Writing to disk after 186804000000 rows
# Writing to disk after 186804100000 rows
# Writing to disk after 186804200000 rows
# Writing to disk after 186804300000 rows
# Writing to disk after 186804400000 rows
# Writing to disk after 186804500000 rows
# Writing to disk after 186804600000 rows
# Writing to disk after 186804700000 rows
# Writing to disk after 186804800000 rows
# Writing to disk after 186804900000 rows
# Writing to disk after 186805000000 rows
# Writing to disk after 186805100000 rows
# Writing to disk after 186805200000 rows
# Writing to disk after 186805300000 rows
# Writing to disk after 186805400000 rows
# Writing to disk after 186805500000 rows
# Writing to disk after 186805600000 rows
# Writing to disk after 186805700000 rows
# Writing to disk after 186805800000 rows
# Writing to disk after 186805900000 rows
# Writing to disk after 186806000000 rows
# Writing to disk after 186806100000 rows
# Writing to disk after 186806200000 rows
# Writing to disk after 186806300000 rows
# Writing to disk after 186806400000 rows
# Writing to disk after 186806500000 rows
# Writing to disk after 186806600000 rows
# Writing to disk after 186806700000 rows
# Writing to disk after 186806800000 rows
# Writing to disk after 186806900000 rows
# Writing to disk after 186807000000 rows
# Writing to disk after 186807100000 rows
# Writing to disk after 186807200000 rows
# Writing to disk after 186807300000 rows
# Writing to disk after 186807400000 rows
# Writing to disk after 186807500000 rows
# Writing to disk after 186807600000 rows
# Writing to disk after 186807700000 rows
# Writing to disk after 186807800000 rows
# Writing to disk after 186807900000 rows
# Writing to disk after 186808000000 rows
# Writing to disk after 186808100000 rows
# Writing to disk after 186808200000 rows
# Writing to disk after 186808300000 rows
# Writing to disk after 186808400000 rows
# Writing to disk after 186808500000 rows
# Writing to disk after 186808600000 rows
# Writing to disk after 186808700000 rows
# Writing to disk after 186808800000 rows
# Writing to disk after 186808900000 rows
# Writing to disk after 186809000000 rows
# Writing to disk after 186809100000 rows
# Writing to disk after 186809200000 rows
# Writing to disk after 186809300000 rows
# Writing to disk after 186809400000 rows
# Writing to disk after 186809500000 rows
# Writing to disk after 186809600000 rows
# Writing to disk after 186809700000 rows
# Writing to disk after 186809800000 rows
# Writing to disk after 186809900000 rows
# Writing to disk after 186810000000 rows
# Writing to disk after 186810100000 rows
# Writing to disk after 186810200000 rows
# Writing to disk after 186810300000 rows
# Writing to disk after 186810400000 rows
# Writing to disk after 186810500000 rows
# Writing to disk after 186810600000 rows
# Writing to disk after 186810700000 rows
# Writing to disk after 186810800000 rows
# Writing to disk after 186810900000 rows
# Writing to disk after 186811000000 rows
# Writing to disk after 186811100000 rows
# Writing to disk after 186811200000 rows
# Writing to disk after 186811300000 rows
# Writing to disk after 186811400000 rows
# Writing to disk after 186811500000 rows
# Writing to disk after 186811600000 rows
# Writing to disk after 186811700000 rows
# Writing to disk after 186811800000 rows
# Writing to disk after 186811900000 rows
# Writing to disk after 186812000000 rows
# Writing to disk after 186812100000 rows
# Writing to disk after 186812200000 rows
# Writing to disk after 186812300000 rows
# Writing to disk after 186812400000 rows
# Writing to disk after 186812500000 rows
# Writing to disk after 186812600000 rows
# Writing to disk after 186812700000 rows
# Writing to disk after 186812800000 rows
# Writing to disk after 186812900000 rows
# Writing to disk after 186813000000 rows
# Writing to disk after 186813100000 rows
# Writing to disk after 186813200000 rows
# Writing to disk after 186813300000 rows
# Writing to disk after 186813400000 rows
# Writing to disk after 186813500000 rows
# Writing to disk after 186813600000 rows
# Writing to disk after 186813700000 rows
# Writing to disk after 186813800000 rows
# Writing to disk after 186813900000 rows
# Writing to disk after 186814000000 rows
# Writing to disk after 186814100000 rows
# Writing to disk after 186814200000 rows
# Writing to disk after 186814300000 rows
# Writing to disk after 186814400000 rows
# Writing to disk after 186814500000 rows
# Writing to disk after 186814600000 rows
# Writing to disk after 186814700000 rows
# Writing to disk after 186814800000 rows
# Writing to disk after 186814900000 rows
# Writing to disk after 186815000000 rows
# Writing to disk after 186815100000 rows
# Writing to disk after 186815200000 rows
# Writing to disk after 186815300000 rows
# Writing to disk after 186815400000 rows
# Writing to disk after 186815500000 rows
# Writing to disk after 186815600000 rows
# Writing to disk after 186815700000 rows
# Writing to disk after 186815800000 rows
# Writing to disk after 186815900000 rows
# Writing to disk after 186816000000 rows
# Writing to disk after 186816100000 rows
# Writing to disk after 186816200000 rows
# Writing to disk after 186816300000 rows
# Writing to disk after 186816400000 rows
# Writing to disk after 186816500000 rows
# Writing to disk after 186816600000 rows
# Writing to disk after 186816700000 rows
# Writing to disk after 186816800000 rows
# Writing to disk after 186816900000 rows
# Writing to disk after 186817000000 rows
# Writing to disk after 186817100000 rows
# Writing to disk after 186817200000 rows
# Writing to disk after 186817300000 rows
# Writing to disk after 186817400000 rows
# Writing to disk after 186817500000 rows
# Writing to disk after 186817600000 rows
# Writing to disk after 186817700000 rows
# Writing to disk after 186817800000 rows
# Writing to disk after 186817900000 rows
# Writing to disk after 186818000000 rows
# Writing to disk after 186818100000 rows
# Writing to disk after 186818200000 rows
# Writing to disk after 186818300000 rows
# Writing to disk after 186818400000 rows
# Writing to disk after 186818500000 rows
# Writing to disk after 186818600000 rows
# Writing to disk after 186818700000 rows
# Writing to disk after 186818800000 rows
# Writing to disk after 186818900000 rows
# Writing to disk after 186819000000 rows
# Writing to disk after 186819100000 rows
# Writing to disk after 186819200000 rows
# Writing to disk after 186819300000 rows
# Writing to disk after 186819400000 rows
# Writing to disk after 186819500000 rows
# Writing to disk after 186819600000 rows
# Writing to disk after 186819700000 rows
# Writing to disk after 186819800000 rows
# Writing to disk after 186819900000 rows
# Writing to disk after 186820000000 rows
# Writing to disk after 186820100000 rows
# Writing to disk after 186820200000 rows
# Writing to disk after 186820300000 rows
# Writing to disk after 186820400000 rows
# Writing to disk after 186820500000 rows
# Writing to disk after 186820600000 rows
# Writing to disk after 186820700000 rows
# Writing to disk after 186820800000 rows
# Writing to disk after 186820900000 rows

# %%
df_data = pd.read_csv('train_tokens.csv',on_bad_lines='warn')

df_data.shape
# Out:
# Skipping line 414344: expected 3 fields, saw 4
# (1868184, 3)

# %%
df_data = df_data[:-1000]

# %%
df_data_correct = df_data.drop(414344,axis=0)

# %%
df_data_correct.iloc[414344]
# Out:
# img_url    http://images.cocodataset.org/train2017/000000...
# input      [ 319  262 7480   30 1858  389  734 3024 6844 ...
# label      [ 262 7480   30 1858  389  734 3024 6844  319 ...
# Name: 414345, dtype: object

# %%
df_data_correct.to_csv('final_train_tokens.csv', index= False)

# %%
df_data = pd.read_csv('final_train_tokens.csv',on_bad_lines='warn')

# %%
df_data.shape
# Out:
# (1868183, 3)

# %%
df_data_1 = pd.read_csv('final_train_tokens.csv',on_bad_lines='skip')

df_data_1.shape

# %% [markdown]
# Preparing Validation data

# %%
data_instruct150_sample_val_flatten = data_instruct150_flatten[-1000:]

# %%
with open('sample_val_data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows([['img_url','q','a']])

with open('sample_val_data.csv', 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data_instruct150_sample_val_flatten)

# %%
df_val_data = pd.read_csv('sample_val_data.csv')

df_val_data.shape
# Out:
# (1000, 3)

# %%
df_val_data.head(2)
# Out:
#                                              img_url  \
# 0  http://images.cocodataset.org/train2017/000000...
# 1  http://images.cocodataset.org/train2017/000000...
#
#                                               q  \
# 0  What are the colors of the dog in the image?
# 1      What animals are present in the image?\n
#
#                                                    a
# 0      The dog in the image has black and brown fur.
# 1  The image shows a group of black and brown she...
